# %% [markdown]
# # Dataset haqida

# %% [markdown]
# Elektron tijorat tendentsiyalarini o'rganish: Soxta ma'lumotlar to'plamidan foydalanish bo'yicha qo'llanma
#
# Kirish:
# Elektron tijorat dunyosida ma'lumotlar kuchli aktivdir, undan mijozlar xatti-harakatlarini tushunish, savdo strategiyalarini yaxshilash va umumiy biznes samaradorligini oshirish uchun foydalanish mumkin. Ushbu qo'llanma elektron tijorat platformasining turli jihatlarini taqlid qilish uchun yaratilgan soxta ma'lumotlar to'plamidan qanday samarali foydalanishni o'rganadi. Ushbu ma'lumotlar to'plamini tahlil qilish orqali korxonalar mahsulot tendentsiyalari, mijozlarning afzalliklari va bozor dinamikasi haqida qimmatli ma'lumotlarga ega bo'lishlari mumkin.

# %% [markdown]
# Ma'lumotlarni tahlil qilish:
# Pandas, NumPy kabi vositalar va Matplotlib yoki Seaborn kabi vizualizatsiya kutubxonalari yordamida ma'lumotlar to'plamini chuqur tahlil qilish mumkin. Eng ko'p sotiladigan mahsulotlar, mashhur mahsulot toifalari, narxlar tendentsiyalari va mavsumiy o'zgarishlar kabi asosiy tushunchalarni tadqiqot ma'lumotlarini tahlil qilish (EDA) orqali olish mumkin. Topilmalarni yaxshiroq tushunish va muloqot qilish uchun intuitiv grafik va diagrammalarni yaratish uchun vizualizatsiya usullaridan foydalanish mumkin.

# %% [markdown]
# ProductID - Mahsulot identifikatori
#
# ProductName - Mahsulot nomi
#
# Category - Turkumi
#
# Price - Narxi
#
# Rating(Item Rating) - Mahsulot reytingi
#
# NumReviews(Number of Reviews) - Fikr bildirganlar/ko'rganlar soni
#
# StockQuantity - Zaxira miqdori(Omborda)
#
# Discount - Chegirma
#
# Sales - Sotish/Sotuvlar
#
# DateAdded - Qo'shilgan sana

# %% [markdown]
# # Hisobotimizning maqsadi

# %% [markdown]
# Maqsadi: Ma'lumotlarni yaxshiroq tushunish va muloqot qilish uchun intuitiv grafik va diagrammalarni yaratish uchun vizualizatsiya usullaridan foydalanish
#
# Kim uchun: Qiziqish bildirganlar uchun

# %% [markdown]
# ## Kutubxonalarni chaqirib olamiz

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Ma'lumotlarni yeg'ish va tayyorlash

# %%
ecommerce = pd.read_csv("ecommerce_product_dataset.csv", index_col=0)
ecommerce.head()
# Out:
#           ProductName     Category   Price  Rating  NumReviews  StockQuantity  \
# ProductID
# 1          Headphones  Electronics  400.31     1.7        3772             20
# 2          Headphones  Electronics  235.03     2.3        2919            663
# 3          Smartwatch  Electronics  417.90     1.8        1184            459
# 4          Smartphone  Electronics  152.70     3.4        2047            475
# 5              Laptop  Electronics  394.74     1.8        1267            831
#
#            Discount  Sales   DateAdded         City
# ProductID
# 1              0.08    466  2023-11-10  Albuquerque
# 2              0.33   1332  2023-09-28       Queens
# 3              0.31    252  2023-10-20       Austin
# 4              0.49   1806  2023-12-05       Dallas
# 5              0.23   1508  2023-08-10       Tucson

# %% [markdown]
# ## Jadval bilan tanishish va uni tahlil qilish

# %%
ecommerce.shape
# Out:
# (1000, 10)

# %%
ecommerce.describe()
# Out:
#             Price       Rating   NumReviews  StockQuantity     Discount  \
# count  1000.00000  1000.000000  1000.000000    1000.000000  1000.000000
# mean    253.77551     3.025600  2498.753000     495.395000     0.251640
# std     141.40362     1.151004  1463.241871     292.799253     0.146455
# min      10.11000     1.000000     3.000000       0.000000     0.000000
# 25%     133.09250     2.100000  1201.750000     241.750000     0.130000
# 50%     251.31000     3.100000  2476.000000     505.000000     0.250000
# 75%     375.82750     4.000000  3797.500000     743.500000     0.380000
# max     499.74000     5.000000  4994.000000     993.000000     0.500000
#
#              Sales
# count  1000.000000
# mean   1011.037000
# std     582.113466
# min       0.000000
# 25%     502.000000
# 50%     998.000000
# 75%    1540.000000
# max    1997.000000

# %%
ecommerce["Category"].value_counts()
# Out:
# Category
# Electronics                   40
# Clothing                      40
# Home & Kitchen                40
# Books                         40
# Toys & Games                  40
# Vitamins and supplements      40
# Skin care                     40
# Makeup                        40
# Coats and jackets             40
# Bicycles                      40
# Art and crafting materials    40
# Drinkware                     40
# Perfume and cologne           40
# Wine                          40
# Socks                         40
# Bedsheets                     40
# Posters and artwork           40
# Candles                       40
# Bath and body                 40
# Cookware                      40
# Nail care                     40
# Underwear                     40
# Motor vehicle parts           40
# Mobile phone accessories      40
# Blankets                      40
# Name: count, dtype: int64

# %%
ecommerce["Category"].value_counts().count()
# Out:
# np.int64(25)

# %% [markdown]
# ## Point plot

# %%
custom_palette = ["red","green","orange","blue","yellow","purple"]
sns.set_palette(custom_palette)
category_names = ecommerce["Category"].unique()
fig, axes = plt.subplots(8, 3, figsize=(20,60), sharey=True)
for ax, category_name  in zip(axes.flatten(), category_names):
    product_name = ecommerce[ecommerce["Category"].isin([category_name])]["ProductName"]
    prices = ecommerce[ecommerce["Category"].isin([category_name])]["Price"]
    catplot = sns.pointplot(x=product_name, y=prices, ax=ax)
    ax.set_title(category_name)
    ax.set_xlabel("Mahsulot nomi")
    ax.set_ylabel("Narxi")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Rudy\AppData\Local\Temp\ipykernel_14740\1198917389.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# C:\Users\Rudy\AppData\Local\Temp\ipykernel_14740\1198917389.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# C:\Users\Rudy\AppData\Local\Temp\ipykernel_14740\1198917389.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# C:\Users\Rudy\AppData\Local\Temp\ipykernel_14740\1198917389.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %% [markdown]
# ## Catplot(Bar)

# %%
sns.set_context("notebook")
sns.catplot(x="Category", y="Price", data=ecommerce, kind="box")
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_context("notebook")
sns.catplot(x="Category", y="Rating", data=ecommerce, kind="box")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Hist

# %%
ecommerce[ecommerce["Category"].isin(["Electronics"])]["Sales"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
ecommerce[ecommerce["Category"].isin(["Electronics"])]["Rating"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
ecommerce[ecommerce["Category"].isin(["Electronics"])]["Price"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Electron mahsulotlarda 100 dollargacha bo'lgan tovarlar ko'proq sotilgan

# %% [markdown]
# ## Histplot

# %%
sns.histplot(ecommerce["Price"])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# 200 dollar atrofidagi tovarlar ko'p sotilgan,

# %%
sns.histplot(ecommerce[ecommerce["Category"].isin(["Electronics"])]["Price"])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# Aynan electron tovarlarda asosan 100 dollargacha bo'lgan tovarlar ko'p sotilgan

# %% [markdown]
# ## Displot

# %%
Electron = ecommerce[ecommerce["Category"].isin(["Electronics"])]
sns.displot(Electron["Price"], kind = "kde")

# %%
sns.displot(Electron["Price"], kde = True, bins = 10)

# %%
sns.displot(Electron["Price"], kind="kde",rug=True, fill = True)

# %%
sns.displot(Electron["Price"], kind = "ecdf")

# %% [markdown]
# Cumulative Sum ishlatilgan

# %% [markdown]
# ## Regplot

# %%
sns.regplot(data = Electron, x="Price", y="Sales")
# Out:
# <Axes: xlabel='Price', ylabel='Sales'>

# %% [markdown]
# Narx oshgan sari Sotuv tushadi

# %%
sns.regplot(data = Electron, x="Price", y="Rating")
# Out:
# <Axes: xlabel='Price', ylabel='Rating'>

# %% [markdown]
# Narxga Tovarlarning reytingini ahamiyati deyarli yo'q

# %%
sns.regplot(data = Electron, y="Sales", x="NumReviews")
# Out:
# <Axes: xlabel='NumReviews', ylabel='Sales'>

# %% [markdown]
# Ko'ranlar soni oshgan sari sotuv hajmi ham oshadi
